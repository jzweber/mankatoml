# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor
import warnings

# %% [markdown]
# # APPL

# %%
warnings.filterwarnings('ignore')
# Load your cleaned data
df = pd.read_csv('aapl_final.csv')

# First, inspect the data and dtypes
print("Data shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head(2))

# Select only numeric columns that make sense for prediction
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns available:", numeric_cols)

# Use numeric columns, excluding index columns
features_to_use = [col for col in numeric_cols if col not in ['Unnamed: 0', 'id']]
print(f"\nUsing features: {features_to_use}")

# Extract data and remove rows with NaN/infinity
data = df[features_to_use].dropna().values
data = data[~np.isinf(data).any(axis=1)]  # Remove rows with infinity values

print(f"Data shape after cleaning: {data.shape}")
print(f"Data type: {data.dtype}")

if data.shape[0] < 35:
    print("WARNING: Not enough data points for sequence length of 30")
    print("Using sequence length of", max(1, data.shape[0] - 5))
    sequence_length = max(1, data.shape[0] - 5)
else:
    sequence_length = 30

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].flatten())
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, sequence_length)

print(f"\nSequences created - X shape: {X.shape}, y shape: {y.shape}")

# Split into train/test (80/20)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train set: X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Test set: X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build neural network model (more stable than LSTM without TensorFlow)
model = MLPRegressor(
    hidden_layer_sizes=(128, 64, 32),
    max_iter=100,
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.1,
    random_state=42,
    verbose=1
)

# Train the model
print("\nTraining model...")
model.fit(X_train, y_train)

# Evaluate
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTrain R² Score: {train_score:.4f}')
print(f'Test R² Score: {test_score:.4f}')

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test)

# Plot results
plt.figure(figsize=(12, 4))
plt.plot(y_test_actual[:100, 0], label='Actual', marker='o', alpha=0.7)
plt.plot(predictions[:100, 0], label='Predicted', marker='x', alpha=0.7)
plt.legend()
plt.title('Neural Network Predictions vs Actual')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()

print("\nModel training complete!")
# Out:
# Data shape: (914962, 30)
#
# Column dtypes:
# Unnamed: 0            int64
# id                    int64
# body                 object
# created_at           object
# user                 object
# source               object
# symbols              object
# owned_symbols        object
# mentioned_users      object
# entities              int64
# conversation         object
# likes                object
# links                object
# reshares             object
# reshare_message      object
# structurable         object
# body_clean           object
# body_no_stopwords    object
# hour                  int64
# minute                int64
# time_period          object
# day_of_week           int64
# day_name             object
# is_weekend            int64
# day_of_month          int64
# month                 int64
# quarter               int64
# week_of_year          int64
# year                  int64
# posts_per_hour        int64
# dtype: object
#
# First few rows:
#    Unnamed: 0         id                                               body  \
# 0        3448  188597609                             $AAPL UN-stoppable! 🎉🥂
# 1        3447  188597670  $AAPL trading flat, then closing over yesterda...
#
#                   created_at  \
# 0  2019-12-31 21:07:39+00:00
# 1  2019-12-31 21:07:56+00:00
#
#                                                 user  \
# 0  {'id': 1623845, 'username': 'escapegrl', 'name...
# 1  {'id': 385977, 'username': 'TheTradingAnalyst'...
#
#                                               source  \
# 0  {'id': 1149, 'title': 'StockTwits for iOS', 'u...
# 1  {'id': 2269, 'title': 'StockTwits Web', 'url':...
#
#                                              symbols  \
# 0  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 1  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
#
#                                        owned_symbols mentioned_users  \
# 0  ['33', '9', '23', '1', '24', '35', '0', '0', '...              []
# 1  ['4', '1', '3', '1', '3', '3', '0', '0', '0', ...              []
#
#    entities  ... time_period day_of_week day_name is_weekend day_of_month  \
# 0         0  ...     evening           1  Tuesday          0           31
# 1         0  ...     evening           1  Tuesday          0           31
#
#   month quarter week_of_year  year  posts_per_hour
# 0    12       4            1  2019               1
# 1    12       4            1  2019               2
#
# [2 rows x 30 columns]
#
# Numeric columns available: ['Unnamed: 0', 'id', 'entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
#
# Using features: ['entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
# Data shape after cleaning: (914962, 11)
# Data type: int64
#
# Sequences created - X shape: (914932, 330), y shape: (914932, 11)
# Train set: X_train shape: (731945, 330), y_train shape: (731945, 11)
# Test set: X_test shape: (182987, 330), y_test shape: (182987, 11)
#
# Training model...
# Iteration 1, loss = 0.00660305
# Validation score: 0.890824
# Iteration 2, loss = 0.00539627
# Validation score: 0.894499
# Iteration 3, loss = 0.00533787
# Validation score: 0.893930
# Iteration 4, loss = 0.00530270
# Validation score: 0.894617
# Iteration 5, loss = 0.00527809
# Validation score: 0.894898
# Iteration 6, loss = 0.00527006
# Validation score: 0.894791
# Iteration 7, loss = 0.00526538
# Validation score: 0.891630
# Iteration 8, loss = 0.00525651
# Validation score: 0.893162
# Iteration 9, loss = 0.00524985
# Validation score: 0.898149
# Iteration 10, loss = 0.00524978
# Validation score: 0.895821
# Iteration 11, loss = 0.00524397
# Validation score: 0.894127
# Iteration 12, loss = 0.00524268
# Validation score: 0.897679
# Iteration 13, loss = 0.00523740
# Validation score: 0.894293
# Iteration 14, loss = 0.00523496
# Validation score: 0.897630
# Iteration 15, loss = 0.00523241
# Validation score: 0.898543
# Iteration 16, loss = 0.00522709
# Validation score: 0.898067
# Iteration 17, loss = 0.00522667
# Validation score: 0.894589
# Iteration 18, loss = 0.00522246
# Validation score: 0.897381
# Iteration 19, loss = 0.00522321
# Validation score: 0.895622
# Iteration 20, loss = 0.00521993
# Validation score: 0.896681
# Iteration 21, loss = 0.00521342
# Validation score: 0.897634
# Iteration 22, loss = 0.00521233
# Validation score: 0.898535
# Iteration 23, loss = 0.00521297
# Validation score: 0.896905
# Iteration 24, loss = 0.00521235
# Validation score: 0.895414
# Iteration 25, loss = 0.00521193
# Validation score: 0.898916
# Iteration 26, loss = 0.00520638
# Validation score: 0.899013
# Iteration 27, loss = 0.00520447
# Validation score: 0.899241
# Iteration 28, loss = 0.00520685
# Validation score: 0.898286
# Iteration 29, loss = 0.00520603
# Validation score: 0.899294
# Iteration 30, loss = 0.00520062
# Validation score: 0.897433
# Iteration 31, loss = 0.00519916
# Validation score: 0.898517
# Iteration 32, loss = 0.00519894
# Validation score: 0.898894
# Iteration 33, loss = 0.00519771
# Validation score: 0.899634
# Iteration 34, loss = 0.00519725
# Validation score: 0.896766
# Iteration 35, loss = 0.00519494
# Validation score: 0.894634
# Iteration 36, loss = 0.00519414
# Validation score: 0.897132
# Iteration 37, loss = 0.00519540
# Validation score: 0.898905
# Iteration 38, loss = 0.00519352
# Validation score: 0.898876
# Iteration 39, loss = 0.00519168
# Validation score: 0.899867
# Iteration 40, loss = 0.00519051
# Validation score: 0.897888
# Iteration 41, loss = 0.00519162
# Validation score: 0.897162
# Iteration 42, loss = 0.00519156
# Validation score: 0.898131
# Iteration 43, loss = 0.00519381
# Validation score: 0.899630
# Iteration 44, loss = 0.00518886
# Validation score: 0.898681
# Iteration 45, loss = 0.00518978
# Validation score: 0.898308
# Iteration 46, loss = 0.00518979
# Validation score: 0.899292
# Iteration 47, loss = 0.00518525
# Validation score: 0.898610
# Iteration 48, loss = 0.00518742
# Validation score: 0.899094
# Iteration 49, loss = 0.00518948
# Validation score: 0.898370
# Iteration 50, loss = 0.00518647
# Validation score: 0.899173
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Train R² Score: 0.9001
# Test R² Score: 0.8910
# Model training complete!

# %% [markdown]
# # AMZN

# %%
warnings.filterwarnings('ignore')
# Load your cleaned data
df = pd.read_csv('amzn_final.csv')

# First, inspect the data and dtypes
print("Data shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head(2))

# Select only numeric columns that make sense for prediction
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns available:", numeric_cols)

# Use numeric columns, excluding index columns
features_to_use = [col for col in numeric_cols if col not in ['Unnamed: 0', 'id']]
print(f"\nUsing features: {features_to_use}")

# Extract data and remove rows with NaN/infinity
data = df[features_to_use].dropna().values
data = data[~np.isinf(data).any(axis=1)]  # Remove rows with infinity values

print(f"Data shape after cleaning: {data.shape}")
print(f"Data type: {data.dtype}")

if data.shape[0] < 35:
    print("WARNING: Not enough data points for sequence length of 30")
    print("Using sequence length of", max(1, data.shape[0] - 5))
    sequence_length = max(1, data.shape[0] - 5)
else:
    sequence_length = 30

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].flatten())
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, sequence_length)

print(f"\nSequences created - X shape: {X.shape}, y shape: {y.shape}")

# Split into train/test (80/20)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train set: X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Test set: X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build neural network model (more stable than LSTM without TensorFlow)
model = MLPRegressor(
    hidden_layer_sizes=(128, 64, 32),
    max_iter=100,
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.1,
    random_state=42,
    verbose=1
)

# Train the model
print("\nTraining model...")
model.fit(X_train, y_train)

# Evaluate
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTrain R² Score: {train_score:.4f}')
print(f'Test R² Score: {test_score:.4f}')

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test)

# Plot results
plt.figure(figsize=(12, 4))
plt.plot(y_test_actual[:100, 0], label='Actual', marker='o', alpha=0.7)
plt.plot(predictions[:100, 0], label='Predicted', marker='x', alpha=0.7)
plt.legend()
plt.title('Neural Network Predictions vs Actual')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()

print("\nModel training complete!")
# Out:
# Data shape: (679409, 17)
#
# Column dtypes:
# Unnamed: 0          int64
# id                 object
# body               object
# created_at         object
# user               object
# source             object
# symbols            object
# mentioned_users    object
# entities            int64
# links              object
# likes              object
# conversation       object
# reshares           object
# reshare_message    object
# owned_symbols      object
# clean_text         object
# body_clean         object
# dtype: object
#
# First few rows:
#    Unnamed: 0         id                                               body  \
# 0           0  171509246  $AMZN $FB $GOOG $AAPL \nSounds like retail inv...
# 1           1  171509284  DOJ isn&#39;t not going after $SNAP !!!  Look ...
#
#                   created_at  \
# 0  2019-07-23 21:14:41+00:00
# 1  2019-07-23 21:15:00+00:00
#
#                                                 user  \
# 0  {'id': 1592585, 'username': 'MAGABULL', 'name'...
# 1  {'id': 551323, 'username': 'optionbro', 'name'...
#
#                                               source  \
# 0  {'id': 1149, 'title': 'StockTwits for iOS', 'u...
# 1  {'id': 2269, 'title': 'StockTwits Web', 'url':...
#
#                                              symbols mentioned_users  \
# 0  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...              []
# 1  [{'id': 864, 'symbol': 'AMZN', 'title': 'Amazo...              []
#
#    entities links                                        likes conversation  \
# 0         0   NaN                                          NaN          NaN
# 1         1   NaN  {'total': 2, 'user_ids': [1630660, 359505]}          NaN
#
#   reshares reshare_message owned_symbols  \
# 0      NaN             NaN           NaN
# 1      NaN             NaN           NaN
#
#                                           clean_text  \
# 0  $amzn $fb $goog $aapl sounds like retail inves...
# 1  doj is not not going after $snap !!! look at r...
#
#                                           body_clean
# 0  $amzn $fb $goog $aapl sounds like retail inves...
# 1  doj is not not going after $snap !!! look at r...
#
# Numeric columns available: ['Unnamed: 0', 'entities']
#
# Using features: ['entities']
# Data shape after cleaning: (679409, 1)
# Data type: int64
#
# Sequences created - X shape: (679379, 30), y shape: (679379, 1)
# Train set: X_train shape: (543503, 30), y_train shape: (543503, 1)
# Test set: X_test shape: (135876, 30), y_test shape: (135876, 1)
#
# Training model...
# Iteration 1, loss = 0.04580412
# Validation score: 0.056554
# Iteration 2, loss = 0.04461552
# Validation score: 0.054477
# Iteration 3, loss = 0.04457531
# Validation score: 0.067280
# Iteration 4, loss = 0.04453120
# Validation score: 0.067206
# Iteration 5, loss = 0.04450987
# Validation score: 0.066749
# Iteration 6, loss = 0.04448201
# Validation score: 0.065645
# Iteration 7, loss = 0.04448648
# Validation score: 0.067280
# Iteration 8, loss = 0.04446888
# Validation score: 0.066766
# Iteration 9, loss = 0.04445465
# Validation score: 0.065034
# Iteration 10, loss = 0.04444929
# Validation score: 0.066845
# Iteration 11, loss = 0.04442918
# Validation score: 0.060737
#
# Train R² Score: 0.0645
# Test R² Score: 0.0000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 81
#      79 # Make predictions
#      80 predictions = model.predict(X_test)
# ---> 81 predictions = scaler.inverse_transform(predictions)
#      82 y_test_actual = scaler.inverse_transform(y_test)
#      84 # Plot results
#
# File g:\Users\jzweb\miniconda3\envs\ml_project\lib\site-packages\sklearn\preprocessing\_data.py:528, in MinMaxScaler.inverse_transform(self, X)
#     514 """Undo the scaling of X according to feature_range.
#     515
#     516 Parameters
#    (...)
#     524     Transformed data.
#     525 """
#     526 check_is_fitted(self)
# --> 528 X = check_array(
#     529     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     530 )
#     532 X -= self.min_
#     533 X /= self.scale_
#
# File g:\Users\jzweb\miniconda3\envs\ml_project\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877     # If input is 1D raise error
#     878     if array.ndim == 1:
# --> 879         raise ValueError(
#     880             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     881             "Reshape your data either using array.reshape(-1, 1) if "
#     882             "your data has a single feature or array.reshape(1, -1) "
#     883             "if it contains a single sample.".format(array)
#     884         )
#     886 if dtype_numeric and array.dtype.kind in "USV":
#     887     raise ValueError(
#     888         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     889         "Convert your data to numeric values explicitly instead."
#     890     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.00274266 0.00274266 0.00274266 ... 0.00274266 0.00274266 0.00274266].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# # FB

# %%
warnings.filterwarnings('ignore')
# Load your cleaned data
df = pd.read_csv('fb_final.csv')

# First, inspect the data and dtypes
print("Data shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head(2))

# Select only numeric columns that make sense for prediction
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns available:", numeric_cols)

# Use numeric columns, excluding index columns
features_to_use = [col for col in numeric_cols if col not in ['Unnamed: 0', 'id']]
print(f"\nUsing features: {features_to_use}")

# Extract data and remove rows with NaN/infinity
data = df[features_to_use].dropna().values
data = data[~np.isinf(data).any(axis=1)]  # Remove rows with infinity values

print(f"Data shape after cleaning: {data.shape}")
print(f"Data type: {data.dtype}")

if data.shape[0] < 35:
    print("WARNING: Not enough data points for sequence length of 30")
    print("Using sequence length of", max(1, data.shape[0] - 5))
    sequence_length = max(1, data.shape[0] - 5)
else:
    sequence_length = 30

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].flatten())
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, sequence_length)

print(f"\nSequences created - X shape: {X.shape}, y shape: {y.shape}")

# Split into train/test (80/20)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train set: X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Test set: X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build neural network model (more stable than LSTM without TensorFlow)
'''Add a dropout layer to prevent overfitting'''
model = MLPRegressor(
    # remove the 128 from the hidden layer and changed the max iter to 15 
    # given that the model was over fitting with the original
    # we figerd a smaller model would be better for this data set
    hidden_layer_sizes=( 64, 32), 
    alpha=0.0001, # add L2 regularization to prevent overfitting
    max_iter=15, 
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.1,
    random_state=42,
    # change verbose to 2 to get more detailed output during training
    # still not sure why the model is overfitting with the original settings
    verbose=2 
)

# Train the model
print("\nTraining model...")
model.fit(X_train, y_train)

# Evaluate
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTrain R² Score: {train_score:.4f}')
print(f'Test R² Score: {test_score:.4f}')

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test)

# Plot results
plt.figure(figsize=(12, 4))
plt.plot(y_test_actual[:100, 0], label='Actual', marker='o', alpha=0.7)
plt.plot(predictions[:100, 0], label='Predicted', marker='x', alpha=0.7)
plt.legend()
plt.title('Neural Network Predictions vs Actual')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()

print("\nModel training complete!")
# Out:
# Data shape: (359908, 29)
#
# Column dtypes:
# Unnamed: 0            int64
# id                    int64
# body                 object
# created_at           object
# user                 object
# source               object
# symbols              object
# mentioned_users      object
# entities              int64
# conversation         object
# likes                object
# links                object
# reshare_message      object
# reshares             object
# owned_symbols        object
# body_clean           object
# body_no_stopwords    object
# hour                  int64
# minute                int64
# time_period          object
# day_of_week           int64
# day_name             object
# is_weekend            int64
# day_of_month          int64
# month                 int64
# quarter               int64
# week_of_year          int64
# year                  int64
# posts_per_hour        int64
# dtype: object
#
# First few rows:
#    Unnamed: 0         id                                               body  \
# 0       14983  171486171                               $FB $205 call buyers
# 1       14982  171486421  $FB \n\nFacebook - Facebook Q2 2019 Earnings\n...
#
#                   created_at  \
# 0  2019-07-23 19:06:54+00:00
# 1  2019-07-23 19:08:16+00:00
#
#                                                 user  \
# 0  {'id': 1138460, 'username': 'Financial3', 'nam...
# 1  {'id': 254908, 'username': 'R436947', 'name': ...
#
#                                               source  \
# 0  {'id': 2095, 'title': 'StockTwits For Android ...
# 1  {'id': 1149, 'title': 'StockTwits for iOS', 'u...
#
#                                              symbols mentioned_users  \
# 0  [{'id': 7871, 'symbol': 'FB', 'title': 'Meta P...              []
# 1  [{'id': 7871, 'symbol': 'FB', 'title': 'Meta P...              []
#
#    entities conversation  ... time_period day_of_week day_name is_weekend  \
# 0         0          NaN  ...     evening           1  Tuesday          0
# 1         0          NaN  ...     evening           1  Tuesday          0
#
#   day_of_month month quarter  week_of_year  year posts_per_hour
# 0           23     7       3            30  2019              1
# 1           23     7       3            30  2019              2
#
# [2 rows x 29 columns]
#
# Numeric columns available: ['Unnamed: 0', 'id', 'entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
#
# Using features: ['entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
# Data shape after cleaning: (359908, 11)
# Data type: int64
#
# Sequences created - X shape: (359878, 330), y shape: (359878, 11)
# Train set: X_train shape: (287902, 330), y_train shape: (287902, 11)
# Test set: X_test shape: (71976, 330), y_test shape: (71976, 11)
#
# Training model...
# Iteration 1, loss = 0.00998245
# Validation score: 0.809138
# Iteration 2, loss = 0.00642852
# Validation score: 0.849770
# Iteration 3, loss = 0.00624322
# Validation score: 0.854265
# Iteration 4, loss = 0.00618318
# Validation score: 0.856505
# Iteration 5, loss = 0.00611520
# Validation score: 0.863316
# Iteration 6, loss = 0.00608182
# Validation score: 0.863215
# Iteration 7, loss = 0.00606127
# Validation score: 0.861055
# Iteration 8, loss = 0.00603746
# Validation score: 0.860181
# Iteration 9, loss = 0.00601921
# Validation score: 0.748989
# Iteration 10, loss = 0.00600759
# Validation score: 0.861162
# Iteration 11, loss = 0.00598810
# Validation score: 0.824850
# Iteration 12, loss = 0.00598636
# Validation score: 0.864792
# Iteration 13, loss = 0.00596582
# Validation score: 0.853771
# Iteration 14, loss = 0.00597138
# Validation score: 0.864652
# Iteration 15, loss = 0.00594990
# Validation score: 0.862375
# Iteration 16, loss = 0.00595134
# Validation score: 0.867736
# Iteration 17, loss = 0.00593686
# Validation score: 0.863897
# Iteration 18, loss = 0.00594247
# Validation score: 0.866702
# Iteration 19, loss = 0.00593284
# Validation score: 0.854545
# Iteration 20, loss = 0.00593170
# Validation score: 0.868239
# Iteration 21, loss = 0.00592981
# Validation score: 0.858430
# Iteration 22, loss = 0.00591970
# Validation score: 0.861491
# Iteration 23, loss = 0.00592716
# Validation score: 0.864031
# Iteration 24, loss = 0.00591796
# Validation score: 0.869082
# Iteration 25, loss = 0.00591185
# Validation score: 0.869488
# Iteration 26, loss = 0.00590374
# Validation score: 0.866708
# Iteration 27, loss = 0.00590587
# Validation score: 0.865311
# Iteration 28, loss = 0.00589961
# Validation score: 0.870523
# Iteration 29, loss = 0.00590740
# Validation score: 0.862589
# Iteration 30, loss = 0.00589321
# Validation score: 0.869096
# Iteration 31, loss = 0.00590800
# Validation score: 0.869464
# Iteration 32, loss = 0.00588785
# Validation score: 0.870750
# Iteration 33, loss = 0.00588724
# Validation score: 0.869790
# Iteration 34, loss = 0.00588598
# Validation score: 0.865017
# Iteration 35, loss = 0.00589344
# Validation score: 0.869947
# Iteration 36, loss = 0.00587652
# Validation score: 0.866616
# Iteration 37, loss = 0.00587813
# Validation score: 0.871147
# Iteration 38, loss = 0.00587291
# Validation score: 0.869465
# Iteration 39, loss = 0.00586400
# Validation score: 0.866635
# Iteration 40, loss = 0.00587217
# Validation score: 0.871384
# Iteration 41, loss = 0.00586745
# Validation score: 0.870487
# Iteration 42, loss = 0.00587267
# Validation score: 0.868731
# Iteration 43, loss = 0.00586030
# Validation score: 0.870546
# Iteration 44, loss = 0.00586551
# Validation score: 0.870068
# Iteration 45, loss = 0.00585596
# Validation score: 0.871133
# Iteration 46, loss = 0.00586188
# Validation score: 0.871378
# Iteration 47, loss = 0.00586400
# Validation score: 0.870299
# Iteration 48, loss = 0.00585753
# Validation score: 0.873187
# Iteration 49, loss = 0.00586051
# Validation score: 0.869610
# Iteration 50, loss = 0.00585570
# Validation score: 0.871075
# Iteration 51, loss = 0.00585449
# Validation score: 0.872158
# Iteration 52, loss = 0.00584439
# Validation score: 0.871583
# Iteration 53, loss = 0.00585087
# Validation score: 0.869505
# Iteration 54, loss = 0.00585133
# Validation score: 0.873093
# Iteration 55, loss = 0.00584377
# Validation score: 0.870387
# Iteration 56, loss = 0.00584759
# Validation score: 0.871920
# Iteration 57, loss = 0.00584655
# Validation score: 0.872472
# Iteration 58, loss = 0.00584611
# Validation score: 0.873107
# Iteration 59, loss = 0.00583866
# Validation score: 0.872681
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Train R² Score: 0.8753
# Test R² Score: -1.8695
# Model training complete!

# %% [markdown]
# # NVDA

# %%
warnings.filterwarnings('ignore')
# Load your cleaned data
df = pd.read_csv('nvda_final.csv')

# First, inspect the data and dtypes
print("Data shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head(2))

# Select only numeric columns that make sense for prediction
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns available:", numeric_cols)

# Use numeric columns, excluding index columns
features_to_use = [col for col in numeric_cols if col not in ['Unnamed: 0', 'id']]
print(f"\nUsing features: {features_to_use}")

# Extract data and remove rows with NaN/infinity
data = df[features_to_use].dropna().values
data = data[~np.isinf(data).any(axis=1)]  # Remove rows with infinity values

print(f"Data shape after cleaning: {data.shape}")
print(f"Data type: {data.dtype}")

if data.shape[0] < 35:
    print("WARNING: Not enough data points for sequence length of 30")
    print("Using sequence length of", max(1, data.shape[0] - 5))
    sequence_length = max(1, data.shape[0] - 5)
else:
    sequence_length = 30

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].flatten())
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, sequence_length)

print(f"\nSequences created - X shape: {X.shape}, y shape: {y.shape}")

# Split into train/test (80/20)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train set: X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Test set: X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build neural network model (more stable than LSTM without TensorFlow)
model = MLPRegressor(
    hidden_layer_sizes=(128, 64, 32),
    max_iter=100,
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.1,
    random_state=42,
    verbose=1
)

# Train the model
print("\nTraining model...")
model.fit(X_train, y_train)

# Evaluate
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTrain R² Score: {train_score:.4f}')
print(f'Test R² Score: {test_score:.4f}')

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test)

# Plot results
plt.figure(figsize=(12, 4))
plt.plot(y_test_actual[:100, 0], label='Actual', marker='o', alpha=0.7)
plt.plot(predictions[:100, 0], label='Predicted', marker='x', alpha=0.7)
plt.legend()
plt.title('Neural Network Predictions vs Actual')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()

print("\nModel training complete!")
# Out:
# Data shape: (584181, 30)
#
# Column dtypes:
# Unnamed: 0            int64
# id                    int64
# body                 object
# created_at           object
# user                 object
# source               object
# symbols              object
# mentioned_users      object
# entities              int64
# likes                object
# conversation         object
# links                object
# reshare_message      object
# reshares             object
# owned_symbols        object
# structurable         object
# body_clean           object
# body_no_stopwords    object
# hour                  int64
# minute                int64
# time_period          object
# day_of_week           int64
# day_name             object
# is_weekend            int64
# day_of_month          int64
# month                 int64
# quarter               int64
# week_of_year          int64
# year                  int64
# posts_per_hour        int64
# dtype: object
#
# First few rows:
#    Unnamed: 0        id                                               body  \
# 0       14999  12994205  $NVDA shorts using a lot of ammo trying to kee...
# 1       14998  12995313  $NVDA quite a rebound today, i can hardly beli...
#
#                   created_at  \
# 0  2013-04-11 19:34:19+00:00
# 1  2013-04-11 20:03:53+00:00
#
#                                                 user  \
# 0  {'id': 18393, 'username': 'fatcoin888', 'name'...
# 1  {'id': 37084, 'username': 'peter5slo', 'name':...
#
#                                               source  \
# 0  {'id': 1, 'title': 'Stocktwits', 'url': 'https...
# 1  {'id': 1, 'title': 'Stocktwits', 'url': 'https...
#
#                                              symbols mentioned_users  \
# 0  [{'id': 2925, 'symbol': 'NVDA', 'title': 'NVID...              []
# 1  [{'id': 2925, 'symbol': 'NVDA', 'title': 'NVID...              []
#
#    entities likes  ... time_period day_of_week  day_name is_weekend  \
# 0         0   NaN  ...     evening           3  Thursday          0
# 1         0   NaN  ...     evening           3  Thursday          0
#
#   day_of_month month quarter week_of_year  year  posts_per_hour
# 0           11     4       2           15  2013               1
# 1           11     4       2           15  2013               1
#
# [2 rows x 30 columns]
#
# Numeric columns available: ['Unnamed: 0', 'id', 'entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
#
# Using features: ['entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
# Data shape after cleaning: (584181, 11)
# Data type: int64
#
# Sequences created - X shape: (584151, 330), y shape: (584151, 11)
# Train set: X_train shape: (467320, 330), y_train shape: (467320, 11)
# Test set: X_test shape: (116831, 330), y_test shape: (116831, 11)
#
# Training model...
# Iteration 1, loss = 0.00799091
# Validation score: 0.851543
# Iteration 2, loss = 0.00589330
# Validation score: 0.858804
# Iteration 3, loss = 0.00578214
# Validation score: 0.858815
# Iteration 4, loss = 0.00572087
# Validation score: 0.860632
# Iteration 5, loss = 0.00568956
# Validation score: 0.862518
# Iteration 6, loss = 0.00566540
# Validation score: 0.863686
# Iteration 7, loss = 0.00563743
# Validation score: 0.853423
# Iteration 8, loss = 0.00562555
# Validation score: 0.861927
# Iteration 9, loss = 0.00560760
# Validation score: 0.865435
# Iteration 10, loss = 0.00558991
# Validation score: 0.864579
# Iteration 11, loss = 0.00559557
# Validation score: 0.860465
# Iteration 12, loss = 0.00557797
# Validation score: 0.865479
# Iteration 13, loss = 0.00557389
# Validation score: 0.854027
# Iteration 14, loss = 0.00557036
# Validation score: 0.866812
# Iteration 15, loss = 0.00556046
# Validation score: 0.855516
# Iteration 16, loss = 0.00555712
# Validation score: 0.865630
# Iteration 17, loss = 0.00556145
# Validation score: 0.850430
# Iteration 18, loss = 0.00555029
# Validation score: 0.856943
# Iteration 19, loss = 0.00555518
# Validation score: 0.866864
# Iteration 20, loss = 0.00555403
# Validation score: 0.867848
# Iteration 21, loss = 0.00554682
# Validation score: 0.862424
# Iteration 22, loss = 0.00554784
# Validation score: 0.863362
# Iteration 23, loss = 0.00554868
# Validation score: 0.865517
# Iteration 24, loss = 0.00554864
# Validation score: 0.865932
# Iteration 25, loss = 0.00554165
# Validation score: 0.864705
# Iteration 26, loss = 0.00554144
# Validation score: 0.867963
# Iteration 27, loss = 0.00553732
# Validation score: 0.868316
# Iteration 28, loss = 0.00553702
# Validation score: 0.867969
# Iteration 29, loss = 0.00553967
# Validation score: 0.866891
# Iteration 30, loss = 0.00553580
# Validation score: 0.867386
# Iteration 31, loss = 0.00553201
# Validation score: 0.868057
# Iteration 32, loss = 0.00552997
# Validation score: 0.865397
# Iteration 33, loss = 0.00553455
# Validation score: 0.864514
# Iteration 34, loss = 0.00552979
# Validation score: 0.866138
# Iteration 35, loss = 0.00552910
# Validation score: 0.868742
# Iteration 36, loss = 0.00552868
# Validation score: 0.867226
# Iteration 37, loss = 0.00552233
# Validation score: 0.867976
# Iteration 38, loss = 0.00552056
# Validation score: 0.868999
# Iteration 39, loss = 0.00552384
# Validation score: 0.869186
# Iteration 40, loss = 0.00552332
# Validation score: 0.868340
# Iteration 41, loss = 0.00551458
# Validation score: 0.867875
# Iteration 42, loss = 0.00551817
# Validation score: 0.865023
# Iteration 43, loss = 0.00551829
# Validation score: 0.867362
# Iteration 44, loss = 0.00551282
# Validation score: 0.867187
# Iteration 45, loss = 0.00551120
# Validation score: 0.869008
# Iteration 46, loss = 0.00552088
# Validation score: 0.869172
# Iteration 47, loss = 0.00551014
# Validation score: 0.869180
# Iteration 48, loss = 0.00551349
# Validation score: 0.869319
# Iteration 49, loss = 0.00551572
# Validation score: 0.869518
# Iteration 50, loss = 0.00551132
# Validation score: 0.868469
# Iteration 51, loss = 0.00551496
# Validation score: 0.869721
# Iteration 52, loss = 0.00550839
# Validation score: 0.865456
# Iteration 53, loss = 0.00551033
# Validation score: 0.869002
# Iteration 54, loss = 0.00551605
# Validation score: 0.869765
# Iteration 55, loss = 0.00551171
# Validation score: 0.869226
# Iteration 56, loss = 0.00551019
# Validation score: 0.866111
# Iteration 57, loss = 0.00551240
# Validation score: 0.867549
# Iteration 58, loss = 0.00551319
# Validation score: 0.869373
# Iteration 59, loss = 0.00550880
# Validation score: 0.868446
# Iteration 60, loss = 0.00550871
# Validation score: 0.869789
# Iteration 61, loss = 0.00551138
# Validation score: 0.870381
# Iteration 62, loss = 0.00550383
# Validation score: 0.868155
# Iteration 63, loss = 0.00550900
# Validation score: 0.869534
# Iteration 64, loss = 0.00551121
# Validation score: 0.868919
# Iteration 65, loss = 0.00551123
# Validation score: 0.869154
# Iteration 66, loss = 0.00550940
# Validation score: 0.868264
# Iteration 67, loss = 0.00550662
# Validation score: 0.865940
# Iteration 68, loss = 0.00550414
# Validation score: 0.867341
# Iteration 69, loss = 0.00550640
# Validation score: 0.868912
# Iteration 70, loss = 0.00550680
# Validation score: 0.868564
# Iteration 71, loss = 0.00550309
# Validation score: 0.868767
# Iteration 72, loss = 0.00551002
# Validation score: 0.869210
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Train R² Score: 0.8715
# Test R² Score: 0.8809
# Model training complete!

# %% [markdown]
# # TSLA

# %%
warnings.filterwarnings('ignore')
# Load your cleaned data
df = pd.read_csv('tsla_final.csv')

# First, inspect the data and dtypes
print("Data shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes)
print("\nFirst few rows:")
print(df.head(2))

# Select only numeric columns that make sense for prediction
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns available:", numeric_cols)

# Use numeric columns, excluding index columns
features_to_use = [col for col in numeric_cols if col not in ['Unnamed: 0', 'id']]
print(f"\nUsing features: {features_to_use}")

# Extract data and remove rows with NaN/infinity
data = df[features_to_use].dropna().values
data = data[~np.isinf(data).any(axis=1)]  # Remove rows with infinity values

print(f"Data shape after cleaning: {data.shape}")
print(f"Data type: {data.dtype}")

if data.shape[0] < 35:
    print("WARNING: Not enough data points for sequence length of 30")
    print("Using sequence length of", max(1, data.shape[0] - 5))
    sequence_length = max(1, data.shape[0] - 5)
else:
    sequence_length = 30

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length].flatten())
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, sequence_length)

print(f"\nSequences created - X shape: {X.shape}, y shape: {y.shape}")

# Split into train/test (80/20)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train set: X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Test set: X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# Build neural network model (more stable than LSTM without TensorFlow)
model = MLPRegressor(
    hidden_layer_sizes=(128, 64, 32),
    max_iter=100,
    learning_rate_init=0.001,
    early_stopping=True,
    validation_fraction=0.1,
    random_state=42,
    verbose=1
)

# Train the model
print("\nTraining model...")
model.fit(X_train, y_train)

# Evaluate
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTrain R² Score: {train_score:.4f}')
print(f'Test R² Score: {test_score:.4f}')

# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test)

# Plot results
plt.figure(figsize=(12, 4))
plt.plot(y_test_actual[:100, 0], label='Actual', marker='o', alpha=0.7)
plt.plot(predictions[:100, 0], label='Predicted', marker='x', alpha=0.7)
plt.legend()
plt.title('Neural Network Predictions vs Actual')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()

print("\nModel training complete!")
# Out:
# Data shape: (2204889, 30)
#
# Column dtypes:
# Unnamed: 0            int64
# id                    int64
# body                 object
# created_at           object
# user                 object
# source               object
# symbols              object
# mentioned_users      object
# entities              int64
# links                object
# likes                object
# conversation         object
# reshare_message      object
# owned_symbols        object
# reshares             object
# structurable         object
# body_clean           object
# body_no_stopwords    object
# hour                  int64
# minute                int64
# time_period          object
# day_of_week           int64
# day_name             object
# is_weekend            int64
# day_of_month          int64
# month                 int64
# quarter               int64
# week_of_year          int64
# year                  int64
# posts_per_hour        int64
# dtype: object
#
# First few rows:
#    Unnamed: 0         id                                               body  \
# 0       14974  188017660                                            $TSLA 🤙
# 1       14973  188017676  $TSLA it so painful holding puts over Xmas but...
#
#                   created_at  \
# 0  2019-12-24 20:45:19+00:00
# 1  2019-12-24 20:45:49+00:00
#
#                                                 user  \
# 0  {'id': 561032, 'username': 'RichOnABoatInMaine...
# 1  {'id': 2025803, 'username': 'NeverGiveUpZ', 'n...
#
#                                               source  \
# 0  {'id': 1149, 'title': 'StockTwits for iOS', 'u...
# 1  {'id': 1149, 'title': 'StockTwits for iOS', 'u...
#
#                                              symbols mentioned_users  \
# 0  [{'id': 8660, 'symbol': 'TSLA', 'title': 'Tesl...              []
# 1  [{'id': 8660, 'symbol': 'TSLA', 'title': 'Tesl...              []
#
#    entities links  ... time_period day_of_week day_name is_weekend  \
# 0         1   NaN  ...     evening           1  Tuesday          0
# 1        -1   NaN  ...     evening           1  Tuesday          0
#
#   day_of_month month quarter week_of_year  year  posts_per_hour
# 0           24    12       4           52  2019               1
# 1           24    12       4           52  2019               2
#
# [2 rows x 30 columns]
#
# Numeric columns available: ['Unnamed: 0', 'id', 'entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
#
# Using features: ['entities', 'hour', 'minute', 'day_of_week', 'is_weekend', 'day_of_month', 'month', 'quarter', 'week_of_year', 'year', 'posts_per_hour']
# Data shape after cleaning: (2204889, 11)
# Data type: int64
#
# Sequences created - X shape: (2204859, 330), y shape: (2204859, 11)
# Train set: X_train shape: (1763887, 330), y_train shape: (1763887, 11)
# Test set: X_test shape: (440972, 330), y_test shape: (440972, 11)
#
# Training model...
# Iteration 1, loss = 0.00618908
# Validation score: 0.899950
# Iteration 2, loss = 0.00564856
# Validation score: 0.902713
# Iteration 3, loss = 0.00560687
# Validation score: 0.902671
# Iteration 4, loss = 0.00558738
# Validation score: 0.902417
# Iteration 5, loss = 0.00557518
# Validation score: 0.902412
# Iteration 6, loss = 0.00556981
# Validation score: 0.904846
# Iteration 7, loss = 0.00556242
# Validation score: 0.904234
# Iteration 8, loss = 0.00555871
# Validation score: 0.904418
# Iteration 9, loss = 0.00555505
# Validation score: 0.903421
# Iteration 10, loss = 0.00555199
# Validation score: 0.902806
# Iteration 11, loss = 0.00554935
# Validation score: 0.904808
# Iteration 12, loss = 0.00554644
# Validation score: 0.903950
# Iteration 13, loss = 0.00554453
# Validation score: 0.904882
# Iteration 14, loss = 0.00554253
# Validation score: 0.905068
# Iteration 15, loss = 0.00554023
# Validation score: 0.905198
# Iteration 16, loss = 0.00554033
# Validation score: 0.905196
# Iteration 17, loss = 0.00553861
# Validation score: 0.905242
# Iteration 18, loss = 0.00553777
# Validation score: 0.905190
# Iteration 19, loss = 0.00553529
# Validation score: 0.903951
# Iteration 20, loss = 0.00553389
# Validation score: 0.905161
# Iteration 21, loss = 0.00553335
# Validation score: 0.905132
# Iteration 22, loss = 0.00553234
# Validation score: 0.905472
# Iteration 23, loss = 0.00553173
# Validation score: 0.905476
# Iteration 24, loss = 0.00552951
# Validation score: 0.905345
# Iteration 25, loss = 0.00553001
# Validation score: 0.905381
# Iteration 26, loss = 0.00553063
# Validation score: 0.905611
# Iteration 27, loss = 0.00552992
# Validation score: 0.905348
# Iteration 28, loss = 0.00552888
# Validation score: 0.905162
# Iteration 29, loss = 0.00552790
# Validation score: 0.905627
# Iteration 30, loss = 0.00552725
# Validation score: 0.905166
# Iteration 31, loss = 0.00552805
# Validation score: 0.905228
# Iteration 32, loss = 0.00552617
# Validation score: 0.905783
# Iteration 33, loss = 0.00552919
# Validation score: 0.905559
# Iteration 34, loss = 0.00552747
# Validation score: 0.905395
# Iteration 35, loss = 0.00552633
# Validation score: 0.905716
# Iteration 36, loss = 0.00552650
# Validation score: 0.905997
# Iteration 37, loss = 0.00552540
# Validation score: 0.905802
# Iteration 38, loss = 0.00552457
# Validation score: 0.905782
# Iteration 39, loss = 0.00552641
# Validation score: 0.905601
# Iteration 40, loss = 0.00552558
# Validation score: 0.905229
# Iteration 41, loss = 0.00552583
# Validation score: 0.905801
# Iteration 42, loss = 0.00552607
# Validation score: 0.904933
# Iteration 43, loss = 0.00552447
# Validation score: 0.905619
# Iteration 44, loss = 0.00552502
# Validation score: 0.905747
# Iteration 45, loss = 0.00552460
# Validation score: 0.905560
# Iteration 46, loss = 0.00552276
# Validation score: 0.906113
# Iteration 47, loss = 0.00552422
# Validation score: 0.905947
# Iteration 48, loss = 0.00552289
# Validation score: 0.905731
# Iteration 49, loss = 0.00552285
# Validation score: 0.905696
# Iteration 50, loss = 0.00552489
# Validation score: 0.905459
# Iteration 51, loss = 0.00552409
# Validation score: 0.905903
# Iteration 52, loss = 0.00552533
# Validation score: 0.905829
# Iteration 53, loss = 0.00552740
# Validation score: 0.905355
# Iteration 54, loss = 0.00552342
# Validation score: 0.905570
# Iteration 55, loss = 0.00552230
# Validation score: 0.905953
# Iteration 56, loss = 0.00552369
# Validation score: 0.905808
# Iteration 57, loss = 0.00552252
# Validation score: 0.903584
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Train R² Score: 0.9064
# Test R² Score: 0.9023
# Model training complete!
